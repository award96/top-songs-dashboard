# %%
import billboard

# %%
chart = billboard.ChartData('hot-100')

# %%
for i, song in enumerate(chart):
#     print(f"\n{i}")
#     print(song.title)
#     print(song.artist)
#     print(song.image)
#     print(song.peakPos)
#     print(song.lastPos)
#     print(song.weeks)
#     print(song.rank)
#     print(song.isNew)
# Out:
#   File "/var/folders/lp/cgkjbm6d28q33c7wy798m6h00000gn/T/ipykernel_55691/4096576674.py", line 10
#     #     print(song.isNew)
#                            ^
# SyntaxError: unexpected EOF while parsing

# %%
chart2 = billboard.ChartData('billboard-global-200')

# %%
for song in chart2:
#     print(song)
# Out:
#   File "/var/folders/lp/cgkjbm6d28q33c7wy798m6h00000gn/T/ipykernel_55691/3143313832.py", line 2
#     #     print(song)
#                      ^
# SyntaxError: unexpected EOF while parsing

# %%
chart3 = billboard.ChartData('hot-100', date="2022-04-28")

# %%
for i in range(len(chart)):
    print("\n", i)
    today, old = chart[i].title, chart3[i].title
    if today == old:
        print("same")
    else:
        print(f"different\n{today}\n{old}")
# Out:
#  0
# same
#
#  1
# same
#
#  2
# same
#
#  3
# same
#
#  4
# same
#
#  5
# same
#
#  6
# different
# Woman
# Don't Think Jesus
#
#  7
# different
# Ghost
# Woman
#
#  8
# same
#
#  9
# different
# Thats What I Want
# Ghost
#
#  10
# different
# Bad Habits
# Thats What I Want
#
#  11
# different
# Shivers
# Bad Habits
#
#  12
# same
#
#  13
# different
# Cold Heart (PNAU Remix)
# Shivers
#
#  14
# different
# Thousand Miles
# Cold Heart (PNAU Remix)
#
#  15
# different
# Save Your Tears
# Easy On Me
#
#  16
# different
# One Right Now
# Need To Know
#
#  17
# different
# Levitating
# Save Your Tears
#
#  18
# different
# Need To Know
# One Right Now
#
#  19
# different
# MAMIII
# In A Minute
#
#  20
# different
# Bam Bam
# Levitating
#
#  21
# different
# Industry Baby
# 'Til You Can't
#
#  22
# different
# 'Til You Can't
# Industry Baby
#
#  23
# different
# Easy On Me
# MAMIII
#
#  24
# different
# In A Minute
# Bam Bam
#
#  25
# different
# Doin' This
# Hrs And Hrs
#
#  26
# different
# Wasted On You
# We Don't Talk About Bruno
#
#  27
# different
# AA
# Right On
#
#  28
# different
# Plan B
# Never Say Never
#
#  29
# different
# Hrs And Hrs
# Doin' This
#
#  30
# different
# Boyfriend
# Wasted On You
#
#  31
# different
# Sweetest Pie
# AA
#
#  32
# different
# Trouble With A Heartbreak
# Good 4 U
#
#  33
# different
# Right On
# Sweetest Pie
#
#  34
# different
# Good 4 U
# Fingers Crossed
#
#  35
# different
# Provenza
# I Hate U
#
#  36
# different
# Numb Little Bug
# Boyfriend
#
#  37
# same
#
#  38
# different
# I Hate U
# You Right
#
#  39
# different
# We Don't Talk About Bruno
# Numb Little Bug
#
#  40
# different
# Never Say Never
# Fancy Like
#
#  41
# different
# Don't Think Jesus
# Sand In My Boots
#
#  42
# different
# You Right
# What Happened To Virgil
#
#  43
# different
# Fingers Crossed
# Pushin P
#
#  44
# different
# Fancy Like
# Beers On Me
#
#  45
# different
# Sand In My Boots
# The Motto
#
#  46
# same
#
#  47
# different
# The Motto
# When You're Gone
#
#  48
# different
# What Happened To Virgil
# Buy Dirt
#
#  49
# different
# When You're Gone
# About Damn Time
#
#  50
# different
# 2step
# Shake It
#
#  51
# different
# Beers On Me
# Light Switch
#
#  52
# different
# Pushin P
# If I Was A Cowboy
#
#  53
# different
# Freaky Deaky
# Peru
#
#  54
# different
# Something In The Orange
# Flowers
#
#  55
# different
# Peru
# Nail Tech
#
#  56
# different
# Hold That Heat
# Freaky Deaky
#
#  57
# different
# If I Was A Cowboy
# 23
#
#  58
# different
# Scrape It Off
# Trouble With A Heartbreak
#
#  59
# different
# About Damn Time
# Broadway Girls
#
#  60
# different
# Tomorrow Me
# Heart On Fire
#
#  61
# different
# Slow Down Summer
# No Love
#
#  62
# different
# Never Wanted To Be That Girl
# Surface Pressure
#
#  63
# different
# Light Switch
# Slow Down Summer
#
#  64
# different
# 23
# Flower Shops
#
#  65
# different
# Me Or Sum
# Never Wanted To Be That Girl
#
#  66
# different
# Broadway Girls
# Me Or Sum
#
#  67
# different
# Flowers
# Ahhh Ha
#
#  68
# different
# No Love
# Give Heaven Some Hell
#
#  69
# different
# Flower Shops
# Handsomer
#
#  70
# different
# Nail Tech
# Envolver
#
#  71
# different
# Give Heaven Some Hell
# Do We Have A Problem?
#
#  72
# same
#
#  73
# different
# Take My Name
# Rumors
#
#  74
# different
# Surface Pressure
# Take My Name
#
#  75
# different
# Neck & Wrist
# Damn Strait
#
#  76
# different
# Handsomer
# Circles Around This Town
#
#  77
# different
# Rock N Roll
# In My Head
#
#  78
# different
# Ahhh Ha
# Nobody Like U
#
#  79
# different
# Do We Have A Problem?
# Soy El Unico
#
#  80
# different
# Dreamin Of The Past
# I Love You So
#
#  81
# different
# Circles Around This Town
# Come Back As A Country Boy
#
#  82
# different
# Damn Strait
# GINE
#
#  83
# different
# Envolver
# City Of Gods
#
#  84
# different
# Shake It
# Complete Mess
#
#  85
# different
# I Love You So
# Leave You Alone
#
#  86
# different
# Rumors
# Bones
#
#  87
# different
# She Likes It
# Banking On Me
#
#  88
# different
# In My Head
# She Likes It
#
#  89
# different
# Soy El Unico
# Pressure
#
#  90
# different
# Leave You Alone
# Desesperados
#
#  91
# different
# Out Of Time
# Over
#
#  92
# different
# Banking On Me
# The Family Madrigal
#
#  93
# different
# Come Back As A Country Boy
# Hate Our Love
#
#  94
# different
# Desesperados
# Dos Oruguitas
#
#  95
# different
# Bones
# P Power
#
#  96
# different
# Hate Our Love
# Money So Big
#
#  97
# different
# Over
# Blick Blick!
#
#  98
# different
# City Of Gods
# Fall In Love
#
#  99
# different
# Brambleton
# X Ultima Vez
