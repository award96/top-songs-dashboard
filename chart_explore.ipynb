# %%
t = (('a', 'z'), ('b', 'y'), ('c', 'x'))
q = list(zip(*t))

# %%
# Out:
# ('z', 'y', 'x')

# %%
import billboard

# %%
import pymysql

# %%
chart = billboard.ChartData('hot-100', '1960-01-02')

# %%
for i, song in enumerate(chart):
    print(song)
#     print(f"\n{i}")
#     print(type(song.title))
#     print(type(song.artist))
#     print(type(song.image))
#     print(type(song.peakPos))
#     print(type(song.lastPos))
#     print(type(song.weeks))
#     print(type(song.rank))
#     print(type(song.isNew))
# Out:
# 'El Paso' by Marty Robbins
# 'Why' by Frankie Avalon
# 'The Big Hurt' by Miss Toni Fisher
# 'Running Bear' by Johnny Preston
# 'Way Down Yonder In New Orleans' by Freddie Cannon
# 'Heartaches By The Number' by Guy Mitchell
# 'It's Time To Cry' by Paul Anka
# 'Among My Souvenirs' by Connie Francis
# 'Pretty Blue Eyes' by Steve Lawrence
# 'Go, Jimmy, Go' by Jimmy Clanton
# 'We Got Love' by Bobby Rydell
# 'Mack The Knife' by Bobby Darin
# 'The Village Of St. Bernadette' by Andy Williams
# 'Uh! Oh! Part 2' by The Nutty Squirrels
# 'Sandy' by Larry Hall
# 'Hound Dog Man' by Fabian
# 'Scarlet Ribbons (For Her Hair)' by The Browns
# 'Smokie - Part 2' by Bill Black's Combo
# 'Not One Minute More' by Della Reese
# 'This Friendly World' by Fabian
# 'In The Mood' by Ernie Fields & Orch.
# 'The Little Drummer Boy' by The Harry Simeone Chorale
# 'You Got What It Takes' by Marv Johnson
# 'First Name Initial' by Annette With The Afterbeats
# 'So Many Ways' by Brook Benton
# ...

# %%
chart2 = billboard.ChartData('billboard-global-200')

# %%
for song in chart2:
#     print(song)
# Out:
#   File "/var/folders/lp/cgkjbm6d28q33c7wy798m6h00000gn/T/ipykernel_55691/3143313832.py", line 2
#     #     print(song)
#                      ^
# SyntaxError: unexpected EOF while parsing

# %%
chart3 = billboard.ChartData('hot-100', date="2022-04-28")

# %%
for i in range(len(chart)):
    print("\n", i)
    today, old = chart[i].title, chart3[i].title
    if today == old:
        print("same")
    else:
        print(f"different\n{today}\n{old}")
# Out:
#  0
# same
#
#  1
# same
#
#  2
# same
#
#  3
# same
#
#  4
# same
#
#  5
# same
#
#  6
# different
# Woman
# Don't Think Jesus
#
#  7
# different
# Ghost
# Woman
#
#  8
# same
#
#  9
# different
# Thats What I Want
# Ghost
#
#  10
# different
# Bad Habits
# Thats What I Want
#
#  11
# different
# Shivers
# Bad Habits
#
#  12
# same
#
#  13
# different
# Cold Heart (PNAU Remix)
# Shivers
#
#  14
# different
# Thousand Miles
# Cold Heart (PNAU Remix)
#
#  15
# different
# Save Your Tears
# Easy On Me
#
#  16
# different
# One Right Now
# Need To Know
#
#  17
# different
# Levitating
# Save Your Tears
#
#  18
# different
# Need To Know
# One Right Now
#
#  19
# different
# MAMIII
# In A Minute
#
#  20
# different
# Bam Bam
# Levitating
#
#  21
# different
# Industry Baby
# 'Til You Can't
#
#  22
# different
# 'Til You Can't
# Industry Baby
#
#  23
# different
# Easy On Me
# MAMIII
#
#  24
# different
# In A Minute
# Bam Bam
#
#  25
# different
# Doin' This
# Hrs And Hrs
#
#  26
# ...

# %%
def compare_two(date1, date2):
    chart1 = billboard.ChartData('hot-100', date=date1)
    chart2 = billboard.ChartData('hot-100', date=date2)
    for i in range(len(chart1)):
        print("\n", i)
        today, old = chart1[i].title, chart2[i].title
        if today == old:
            pass
        else:
            print(f"different\n{today}\n{old}")

# %%
compare_two('1960-01-01', '1960-01-05')
# Out:
#  0
# same
#
#  1
# same
#
#  2
# different
# The Big Hurt
# Way Down Yonder In New Orleans
#
#  3
# same
#
#  4
# different
# Way Down Yonder In New Orleans
# The Big Hurt
#
#  5
# different
# Heartaches By The Number
# It's Time To Cry
#
#  6
# different
# It's Time To Cry
# Go, Jimmy, Go
#
#  7
# same
#
#  8
# same
#
#  9
# different
# Go, Jimmy, Go
# Heartaches By The Number
#
#  10
# different
# We Got Love
# Hound Dog Man
#
#  11
# different
# Mack The Knife
# The Village Of St. Bernadette
#
#  12
# different
# The Village Of St. Bernadette
# Mack The Knife
#
#  13
# different
# Uh! Oh! Part 2
# Teen Angel
#
#  14
# different
# Sandy
# You Got What It Takes
#
#  15
# different
# Hound Dog Man
# Not One Minute More
#
#  16
# different
# Scarlet Ribbons (For Her Hair)
# Smokie - Part 2
#
#  17
# different
# Smokie - Part 2
# We Got Love
#
#  18
# different
# Not One Minute More
# Sandy
#
#  19
# different
# This Friendly World
# First Name Initial
#
#  20
# different
# ...
